# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import os
import numpy as np

# List all files in a directory using os.listdir
basepath = 'C:\Academic\ECE - 4370 (Machine_Learning)\Assignments\Assignment_4\Celegans_ModelGen/1'
images = []
""" for class_file in os.listdir(basepath): """
for image in os.listdir(basepath):
    if os.path.isfile(os.path.join(basepath, image)):
        img = mpimg.imread(os.path.join(basepath, image))
        arr_img = img.reshape([10201])
        images.append(arr_img)

# %%
plt.imshow(images[0])

# %%
arr_img = images[0].reshape([10201])

# %%
len(arr_img)
# Out:
# 10201

# %%
np.max(images[1])
# Out:
# 0.9019608

# %%
""" f, axes = plt.subplots(2, 5, figsize=(25, 15))
axes = axes.ravel()
for i in range(2):
    disp = ConfusionMatrixDisplay(multilabel_confusion_matrix(t[:, i], 
                                                              Y[:, i],),
                                                              display_labels=[0, i])

    disp.plot(ax=axes[i], values_format='.4g')
    disp.ax_set_title(f'class {i}')
    if i<10:
        disp.ax_set_xlabel('')
    if i%5!=0:
        disp.ax_set_ylabel('')
    disp.im_colorbar.remove()

plt.subpltos_adjust(wspace=0.10, hspace=0.1)
f.colorbar(disp.im_, ax=axes)
plt.show() """
